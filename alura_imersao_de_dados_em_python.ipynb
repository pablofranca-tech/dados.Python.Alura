# %% [markdown]
# <a href="https://colab.research.google.com/github/pablofranca-tech/dados.Python.Alura/blob/main/alura_imersao_de_dados_em_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Aula 01

# %%
import pandas as pd

# %%
df = pd.read_csv("https://raw.githubusercontent.com/guilhermeonrails/data-jobs/refs/heads/main/salaries.csv")

# %%
df.head(10)
# Out:
#    work_year experience_level employment_type           job_title  salary  \
# 0     2025.0               SE              FT  Solutions Engineer  214000
# 1     2025.0               SE              FT  Solutions Engineer  136000
# 2     2025.0               MI              FT       Data Engineer  158800
# 3     2025.0               MI              FT       Data Engineer  139200
# 4     2025.0               EN              FT       Data Engineer   90000
# 5     2025.0               EN              FT       Data Engineer   80000
# 6     2025.0               SE              FT      Data Scientist  185000
# 7     2025.0               SE              FT      Data Scientist  148000
# 8     2025.0               MI              FT      Data Scientist  135000
# 9     2025.0               MI              FT      Data Scientist  108000
#
#   salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0             USD         214000                 US           100
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 133349 entries, 0 to 133348
# Data columns (total 11 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   work_year           133339 non-null  float64
#  1   experience_level    133349 non-null  object
#  2   employment_type     133349 non-null  object
#  3   job_title           133349 non-null  object
#  4   salary              133349 non-null  int64
#  5   salary_currency     133349 non-null  object
#  6   salary_in_usd       133349 non-null  int64
#  7   employee_residence  133349 non-null  object
#  8   remote_ratio        133349 non-null  int64
#  9   company_location    133349 non-null  object
#  10  company_size        133349 non-null  object
# dtypes: float64(1), int64(3), object(7)
# memory usage: 11.2+ MB

# %%
df.describe()
# Out:
#            work_year        salary  salary_in_usd   remote_ratio
# count  133339.000000  1.333490e+05  133349.000000  133349.000000
# mean     2024.358770  1.632833e+05  157617.272098      20.905669
# std         0.680627  2.173860e+05   74288.363097      40.590044
# min      2020.000000  1.400000e+04   15000.000000       0.000000
# 25%      2024.000000  1.060200e+05  106000.000000       0.000000
# 50%      2024.000000  1.470000e+05  146206.000000       0.000000
# 75%      2025.000000  1.990000e+05  198000.000000       0.000000
# max      2025.000000  3.040000e+07  800000.000000     100.000000

# %%
df.shape
# Out:
# (133349, 11)

# %%
linhas, colunas = df.shape[0], df.shape[1]
print("Numeros de linhas:", linhas)
print("Numero de colunas:", colunas)
# Out:
# Numeros de linhas: 133349
# Numero de colunas: 11

# %%
renomear_colunas = {
    'work_year': 'ano',
    'experience_level': 'experiencia',
    'employment_type': 'contrato',
    'job_title': 'cargo',
    'salary': 'salario',
    'salary_currency': 'salario',
    'salary_in_usd': 'usd',
    'employee_residence': 'residencia',
    'remote_ratio': 'remoto',
    'company_location': 'empresa',
    'company_size': 'tamanho_empresa'
}

df.rename(columns=renomear_colunas, inplace=True)
df.columns
# Out:
# Index(['ano', 'experiencia', 'contrato', 'cargo', 'salario', 'salario', 'usd',
#        'residencia', 'remoto', 'empresa', 'tamanho_empresa'],
#       dtype='object')

# %%
df["experiencia"].value_counts()
# Out:
# experiencia
# SE    77241
# MI    40465
# EN    12443
# EX     3200
# Name: count, dtype: int64

# %%
df["contrato"].value_counts()
# Out:
# contrato
# FT    132563
# CT       394
# PT       376
# FL        16
# Name: count, dtype: int64

# %%
df["remoto"].value_counts()
# Out:
# remoto
# 0      105312
# 100     27718
# 50        319
# Name: count, dtype: int64

# %%
df["tamanho_empresa"].value_counts()
# Out:
# tamanho_empresa
# M    129561
# L      3574
# S       214
# Name: count, dtype: int64

# %%
df["empresa"].value_counts()
# Out:
# empresa
# US    119641
# CA      5239
# GB      3719
# AU       522
# NL       404
#        ...
# IR         1
# BS         1
# IQ         1
# CN         1
# MD         1
# Name: count, Length: 95, dtype: int64

# %%
traducao_experiencia = {
    'SE': 'Senior',
    'MI': 'Pleno',
    'EN': 'Junior',
    'EX': 'Executivo'
}

df['experiencia'] = df['experiencia'].map(traducao_experiencia)
display(df['experiencia'].value_counts())
# Out:
# experiencia
# Senior       77241
# Pleno        40465
# Junior       12443
# Executivo     3200
# Name: count, dtype: int64

# %%
traducao_contrato = {
    'FT': 'Tempo Integral',
    'CT': 'Contrato',
    'PT': 'Tempo Parcial',
    'FL': 'Freelancer'
}

df['contrato'] = df['contrato'].map(traducao_contrato)
display(df['contrato'].value_counts())
# Out:
# contrato
# Tempo Integral    132563
# Contrato             394
# Tempo Parcial        376
# Freelancer            16
# Name: count, dtype: int64

# %%
traducao_remoto = {
    0: 'Presencial',
    50: 'Híbrido',
    100: 'Remoto'
}

df['remoto'] = df['remoto'].map(traducao_remoto)
display(df['remoto'].value_counts())
# Out:
# remoto
# Presencial    105312
# Remoto         27718
# Híbrido          319
# Name: count, dtype: int64

# %%
traducao_tamanho_empresa = {
    'M': 'Médio',
    'L': 'Grande',
    'S': 'Pequeno'
}

df['tamanho_empresa'] = df['tamanho_empresa'].map(traducao_tamanho_empresa)
display(df['tamanho_empresa'].value_counts())
# Out:
# tamanho_empresa
# Médio      129561
# Grande       3574
# Pequeno       214
# Name: count, dtype: int64

# %%
df.head()
# Out:
#       ano experiencia        contrato               cargo salario salario  \
# 0  2025.0      Senior  Tempo Integral  Solutions Engineer  214000     USD
# 1  2025.0      Senior  Tempo Integral  Solutions Engineer  136000     USD
# 2  2025.0       Pleno  Tempo Integral       Data Engineer  158800     USD
# 3  2025.0       Pleno  Tempo Integral       Data Engineer  139200     USD
# 4  2025.0      Junior  Tempo Integral       Data Engineer   90000     USD
#
#       usd residencia      remoto empresa tamanho_empresa
# 0  214000         US      Remoto      US           Médio
# 1  136000         US      Remoto      US           Médio
# 2  158800         AU  Presencial      AU           Médio
# 3  139200         AU  Presencial      AU           Médio
# 4   90000         US  Presencial      US           Médio

# %%
df.describe(include='object')
# Out:
#        experiencia        contrato           cargo salario residencia  \
# count       133349          133349          133349  133349     133349
# unique           4               4             390      26        102
# top         Senior  Tempo Integral  Data Scientist     USD         US
# freq         77241          132563           17314  126140     119579
#
#             remoto empresa tamanho_empresa
# count       133349  133349          133349
# unique           3      95               3
# top     Presencial      US           Médio
# freq        105312  119641          129561

# %% [markdown]
# Aula 02

# %%
df.isnull()
# Out:
#           ano  experiencia  contrato  cargo  salario  salario    usd  \
# 0       False        False     False  False    False    False  False
# 1       False        False     False  False    False    False  False
# 2       False        False     False  False    False    False  False
# 3       False        False     False  False    False    False  False
# 4       False        False     False  False    False    False  False
# ...       ...          ...       ...    ...      ...      ...    ...
# 133344  False        False     False  False    False    False  False
# 133345  False        False     False  False    False    False  False
# 133346  False        False     False  False    False    False  False
# 133347  False        False     False  False    False    False  False
# 133348  False        False     False  False    False    False  False
#
#         residencia  remoto  empresa  tamanho_empresa
# 0            False   False    False            False
# ...

# %%
df.head()
# Out:
#       ano experiencia        contrato               cargo salario salario  \
# 0  2025.0      Senior  Tempo Integral  Solutions Engineer  214000     USD
# 1  2025.0      Senior  Tempo Integral  Solutions Engineer  136000     USD
# 2  2025.0       Pleno  Tempo Integral       Data Engineer  158800     USD
# 3  2025.0       Pleno  Tempo Integral       Data Engineer  139200     USD
# 4  2025.0      Junior  Tempo Integral       Data Engineer   90000     USD
#
#       usd residencia      remoto empresa tamanho_empresa
# 0  214000         US      Remoto      US           Médio
# 1  136000         US      Remoto      US           Médio
# 2  158800         AU  Presencial      AU           Médio
# 3  139200         AU  Presencial      AU           Médio
# 4   90000         US  Presencial      US           Médio

# %%
df.isnull().sum()
# Out:
# ano                10
# experiencia         0
# contrato            0
# cargo               0
# salario             0
# salario             0
# usd                 0
# residencia          0
# remoto              0
# empresa             0
# tamanho_empresa     0
# dtype: int64

# %%
df['ano'].unique()
# Out:
# array([2025.,   nan, 2024., 2022., 2023., 2020., 2021.])

# %%
df[df.isnull().any(axis=1)]
# Out:
#         ano experiencia        contrato                      cargo salario  \
# 5588    NaN      Senior  Tempo Integral            Product Manager  184500
# 59692   NaN       Pleno  Tempo Integral                   Engineer  110000
# 59710   NaN      Junior  Tempo Integral             Data Scientist  208800
# 59759   NaN      Senior  Tempo Integral          Software Engineer  135000
# 59789   NaN      Senior  Tempo Integral                   Engineer  112000
# 131000  NaN      Senior  Tempo Integral  Machine Learning Engineer  163800
# 131006  NaN      Senior  Tempo Integral     Data Analytics Manager  204500
# 133054  NaN      Junior  Tempo Integral             Data Scientist   40000
# 133281  NaN       Pleno  Tempo Integral  Machine Learning Engineer  180000
# 133317  NaN       Pleno  Tempo Integral             Data Scientist  130000
#
#        salario     usd residencia      remoto empresa tamanho_empresa
# 5588       USD  184500         US  Presencial      US           Médio
# ...

# %%
import numpy as np

''' criaçao de um dataframe com salarios nulos'''

df_salarios = pd.DataFrame([
     {"nome": 'ana', "salario": 4000},
     {"nome": 'Pablo', "salario": np.nan},
     {"nome": 'Leticia', "salario": 50000},
     {"nome": 'Valeria', "salario": np.nan},
     {"nome": 'Daniela', "salario": 3000}
])
#calcula a media e substitui os nulos pela medias e a redonda

df_salarios['salario_media'] = df_salarios['salario'].fillna(df_salarios['salario'].mean().round(2))

df_salarios['salario_mediana'] = df_salarios['salario'].fillna(df_salarios['salario'].median())

display(df_salarios)
# Out:
#       nome  salario  salario_media  salario_mediana
# 0      ana   4000.0         4000.0           4000.0
# 1    Pablo      NaN        19000.0           4000.0
# 2  Leticia  50000.0        50000.0          50000.0
# 3  Valeria      NaN        19000.0           4000.0
# 4  Daniela   3000.0         3000.0           3000.0

# %%
import numpy as np

'''criaçao de um dataframe com salarios nulos'''

df_temperaturas = pd.DataFrame({
     "dia": ['segunda', 'terça', 'quarta', 'quinta', 'sexta'],
     "temperatura": [30, np.nan, np.nan, 27, 28]

})
df_temperaturas['Preenchido_ffill'] = df_temperaturas['temperatura'].ffill()
display(df_temperaturas)
# Out:
#        dia  temperatura  Preenchido_ffill
# 0  segunda         30.0              30.0
# 1    terça          NaN              30.0
# 2   quarta          NaN              30.0
# 3   quinta         27.0              27.0
# 4    sexta         28.0              28.0

# %%
import numpy as np

'''criaçao de um dataframe com salarios nulos'''

df_temperaturas = pd.DataFrame({
     "dia": ['segunda', 'terça', 'quarta', 'quinta', 'sexta'],
     "temperatura": [30, np.nan, np.nan, 27, 28]

})
df_temperaturas['Preenchido_bfill'] = df_temperaturas['temperatura'].bfill()
display(df_temperaturas)
# Out:
#        dia  temperatura  Preenchido_bfill
# 0  segunda         30.0              30.0
# 1    terça          NaN              27.0
# 2   quarta          NaN              27.0
# 3   quinta         27.0              27.0
# 4    sexta         28.0              28.0

# %%
import pandas as pd
import numpy as np

df_cidades = pd.DataFrame([
     {"nome": 'ana', "cidade": 'São Paulo'},
     {"nome": 'Pablo', "cidade": np.nan},
     {"nome": 'Leticia', "cidade": np.nan},
     {"nome": 'Valeria', "cidade": 'Parana'},
     {"nome": 'Daniela', "cidade": 'Bahia'}
])

df_cidades['cidades_preenchida'] = df_cidades['cidade'].fillna('Não informados')

(df_cidades)
# Out:
#       nome     cidade cidades_preenchida
# 0      ana  São Paulo          São Paulo
# 1    Pablo        NaN     Não informados
# 2  Leticia        NaN     Não informados
# 3  Valeria     Parana             Parana
# 4  Daniela      Bahia              Bahia

# %%
df_limpo = df.dropna()

# %%
df_limpo.isnull().sum()
# Out:
# ano                0
# experiencia        0
# contrato           0
# cargo              0
# salario            0
# salario            0
# usd                0
# residencia         0
# remoto             0
# empresa            0
# tamanho_empresa    0
# dtype: int64

# %%
df_limpo.head()
# Out:
#       ano experiencia        contrato               cargo salario salario  \
# 0  2025.0      Senior  Tempo Integral  Solutions Engineer  214000     USD
# 1  2025.0      Senior  Tempo Integral  Solutions Engineer  136000     USD
# 2  2025.0       Pleno  Tempo Integral       Data Engineer  158800     USD
# 3  2025.0       Pleno  Tempo Integral       Data Engineer  139200     USD
# 4  2025.0      Junior  Tempo Integral       Data Engineer   90000     USD
#
#       usd residencia      remoto empresa tamanho_empresa
# 0  214000         US      Remoto      US           Médio
# 1  136000         US      Remoto      US           Médio
# 2  158800         AU  Presencial      AU           Médio
# 3  139200         AU  Presencial      AU           Médio
# 4   90000         US  Presencial      US           Médio

# %%
df_limpo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 133339 entries, 0 to 133348
# Data columns (total 11 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   ano              133339 non-null  float64
#  1   experiencia      133339 non-null  object
#  2   contrato         133339 non-null  object
#  3   cargo            133339 non-null  object
#  4   salario          133339 non-null  int64
#  5   salario          133339 non-null  object
#  6   usd              133339 non-null  int64
#  7   residencia       133339 non-null  object
#  8   remoto           133339 non-null  object
#  9   empresa          133339 non-null  object
#  10  tamanho_empresa  133339 non-null  object
# dtypes: float64(1), int64(2), object(8)
# memory usage: 12.2+ MB

# %%
df_limpo = df_limpo.assign(ano = df_limpo['ano'].astype('int64'))

# %%
df_limpo.head()
# Out:
#     ano experiencia        contrato               cargo salario salario  \
# 0  2025      Senior  Tempo Integral  Solutions Engineer  214000     USD
# 1  2025      Senior  Tempo Integral  Solutions Engineer  136000     USD
# 2  2025       Pleno  Tempo Integral       Data Engineer  158800     USD
# 3  2025       Pleno  Tempo Integral       Data Engineer  139200     USD
# 4  2025      Junior  Tempo Integral       Data Engineer   90000     USD
#
#       usd residencia      remoto empresa tamanho_empresa
# 0  214000         US      Remoto      US           Médio
# 1  136000         US      Remoto      US           Médio
# 2  158800         AU  Presencial      AU           Médio
# 3  139200         AU  Presencial      AU           Médio
# 4   90000         US  Presencial      US           Médio

# %% [markdown]
# Aula 03

# %%
df_limpo['experiencia'].value_counts().plot(kind='bar', title = 'Experiencia')
# Out:
# <Axes: title={'center': 'Experiencia'}, xlabel='experiencia'>

# %%
import seaborn as sns

# %%
sns.barplot(data = df_limpo, x= 'experiencia', y = 'usd')
# Out:
# <Axes: xlabel='experiencia', ylabel='usd'>

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(8,4))
sns.barplot(data=df_limpo, x='experiencia', y='usd')
plt.title('Distribuição de Salários por Nível de Experiência')
plt.xlabel('Nível de Experiência')
plt.ylabel('Salário anual (USD)')
plt.show()

# %%
df_limpo.groupby('experiencia')['usd'].mean().sort_values(ascending=False)
# Out:
# experiencia
# Executivo    202027.667813
# Senior       172850.838301
# Pleno        143044.845979
# Junior        99034.963267
# Name: usd, dtype: float64

# %%
df_limpo.groupby('experiencia')['usd'].mean().sort_values(ascending=True).index
# Out:
# Index(['Junior', 'Pleno', 'Senior', 'Executivo'], dtype='object', name='experiencia')

# %%
ordem = df_limpo.groupby('experiencia')['usd'].mean().sort_values(ascending=True).index

# %%
plt.figure(figsize=(8, 4))
sns.barplot(data=df_limpo, x='experiencia', y='usd', order=ordem)
plt.title('Distribuição de Salários por Nível de Experiência')
plt.xlabel('Nível de Experiência')
plt.ylabel('Salário anual (USD)')
plt.show()

# %%
plt.figure(figsize=(8, 4))
sns.histplot(df_limpo['usd'], bins=50, kde=True)
plt.title('Distribuição de Salários Anuais')
plt.xlabel('Salário anual (USD)')
plt.ylabel('Frequência')
plt.show()

# %%
plt.figure(figsize=(8, 4))
sns.boxplot(data=df_limpo, x='experiencia')
plt.title('Distribuição de Salários por Nível de Experiência')
plt.xlabel('Nível de Experiência')
plt.ylabel('Salário anual (USD)')
plt.show()

# %%
plt.figure(figsize=(8, 4))
sns.boxplot(x='experiencia', y='usd', data=df_limpo, order=ordem)
plt.title('Distribuição de Salários por Nível de Experiência')
plt.xlabel('Nível de Experiência')
plt.ylabel('Salário anual (USD)')
plt.show()

# %%
plt.figure(figsize=(8, 4))
sns.boxplot(x='experiencia', y='usd', data=df_limpo, order=ordem, palette='Set2')
plt.title('Distribuição de Salários por Nível de Experiência')
plt.xlabel('Nível de Experiência')
plt.ylabel('Salário anual (USD)')
plt.show()
# Out:
# /tmp/ipython-input-2767576036.py:2: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.

# %%
import plotly.express as px

# %%
import plotly.express as px

df_grouped = df_limpo.groupby('experiencia')['usd'].mean().reset_index()
fig = px.bar(df_grouped, x='experiencia', y='usd', title='Média Salarial por Nível de Experiência (USD)')
fig.update_layout(xaxis_title='Nível de Experiência', yaxis_title='Média Salarial (USD)')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
remota_contagem = df_limpo['remoto'].value_counts().reset_index()
remota_contagem.columns = ['tipo_trabalho', 'quantidade']

fig =px.pie(remota_contagem, names='tipo_trabalho', values='quantidade', title='Distribuição de Tipo de Trabalho Remoto')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
remota_contagem = df_limpo['remoto'].value_counts().reset_index()
remota_contagem.columns = ['tipo_trabalho', 'quantidade']

fig =px.pie(remota_contagem, names='tipo_trabalho', values='quantidade', title='Distribuição de Tipo de Trabalho Remoto', hole=0.5)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
remota_contagem = df_limpo['remoto'].value_counts().reset_index()
remota_contagem.columns = ['tipo_trabalho', 'quantidade']

fig =px.pie(remota_contagem, names='tipo_trabalho', values='quantidade', title='Distribuição de Tipo de Trabalho Remoto', hole=0.3)
fig.update_traces(textinfo='percent+label')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import plotly.express as px

media_salario_por_pais = df_limpo.groupby('empresa')['usd'].mean().reset_index()
fig = px.bar(media_salario_por_pais, x='empresa', y='usd', title='Média Salarial por País (USD)')
fig.update_layout(xaxis_title='País', yaxis_title='Média Salarial (USD)')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import plotly.express as px

# %%
# prompt: Crie um gráfico de média salarial por senioridade em barras usando o plotly

# Load the data and perform necessary cleaning and transformations to define df_limpo
import pandas as pd
df = pd.read_csv("https://raw.githubusercontent.com/guilhermeonrails/data-jobs/refs/heads/main/salaries.csv")

renomear_colunas = {
    'work_year': 'ano',
    'experience_level': 'experiencia',
    'employment_type': 'contrato',
    'job_title': 'cargo',
    'salary': 'salario',
    'salary_currency': 'salario',
    'salary_in_usd': 'usd',
    'employee_residence': 'residencia',
    'remote_ratio': 'remoto',
    'company_location': 'empresa',
    'company_size': 'tamanho_empresa'
}
df.rename(columns=renomear_colunas, inplace=True)

traducao_experiencia = {
    'SE': 'Senior',
    'MI': 'Pleno',
    'EN': 'Junior',
    'EX': 'Executivo'
}
df['experiencia'] = df['experiencia'].map(traducao_experiencia)

traducao_contrato = {
    'FT': 'Tempo Integral',
    'CT': 'Contrato',
    'PT': 'Tempo Parcial',
    'FL': 'Freelancer'
}
df['contrato'] = df['contrato'].map(traducao_contrato)

traducao_remoto = {
    0: 'Presencial',
    50: 'Híbrido',
    100: 'Remoto'
}
df['remoto'] = df['remoto'].map(traducao_remoto)

traducao_tamanho_empresa = {
    'M': 'Médio',
    'L': 'Grande',
    'S': 'Pequeno'
}
df['tamanho_empresa'] = df['tamanho_empresa'].map(traducao_tamanho_empresa)

df_limpo = df.dropna()
df_limpo = df_limpo.assign(ano = df_limpo['ano'].astype('int64'))

import plotly.express as px

senioridade_media_salario = df_limpo.groupby('experiencia')['usd'].mean().sort_values(ascending=False).reset_index()

fig = px.bar(senioridade_media_salario,
             x='experiencia',
             y='usd',
             title='Média Salarial por Experiencia',
             labels={'experiencia': 'Nível de Experiencia', 'usd': 'Média Salarial Anual (USD)'})

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
remoto_contagem = df_limpo['remoto'].value_counts().reset_index()
remoto_contagem.columns = ['tipo_trabalho', 'quantidade']

fig = px.pie(remoto_contagem,
             names='tipo_trabalho',
             values='quantidade',
             title='Proporção dos tipos de trabalho'

          )

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df.head()
# Out:
#       ano experiencia        contrato               cargo salario salario  \
# 0  2025.0      Senior  Tempo Integral  Solutions Engineer  214000     USD
# 1  2025.0      Senior  Tempo Integral  Solutions Engineer  136000     USD
# 2  2025.0       Pleno  Tempo Integral       Data Engineer  158800     USD
# 3  2025.0       Pleno  Tempo Integral       Data Engineer  139200     USD
# 4  2025.0      Junior  Tempo Integral       Data Engineer   90000     USD
#
#       usd residencia      remoto empresa tamanho_empresa
# 0  214000         US      Remoto      US           Médio
# 1  136000         US      Remoto      US           Médio
# 2  158800         AU  Presencial      AU           Médio
# 3  139200         AU  Presencial      AU           Médio
# 4   90000         US  Presencial      US           Médio

# %%
pip install pycountry

# %%
import pycountry

# Função para converter ISO-2 para ISO-3
def iso2_to_iso3(code):
    try:
        return pycountry.countries.get(alpha_2=code).alpha_3
    except:
        return None

# Criar nova coluna com código ISO-3
df_limpo['residencia_iso3'] = df_limpo['residencia'].apply(iso2_to_iso3)

# Calcular média salarial por país (ISO-3)
df_ds = df_limpo[df_limpo['cargo'] == 'Data Scientist']
media_ds_pais = df_ds.groupby('residencia_iso3')['usd'].mean().reset_index()

# Gerar o mapa
fig = px.choropleth(media_ds_pais,
                    locations='residencia_iso3',
                    color='usd',
                    color_continuous_scale='rdylgn',
                    title='Salário médio de Cientista de Dados por país',
                    labels={'usd': 'Salário médio (USD)', 'residencia_iso3': 'País'})

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df_limpo.head()
# Out:
#     ano experiencia        contrato               cargo salario salario  \
# 0  2025      Senior  Tempo Integral  Solutions Engineer  214000     USD
# 1  2025      Senior  Tempo Integral  Solutions Engineer  136000     USD
# 2  2025       Pleno  Tempo Integral       Data Engineer  158800     USD
# 3  2025       Pleno  Tempo Integral       Data Engineer  139200     USD
# 4  2025      Junior  Tempo Integral       Data Engineer   90000     USD
#
#       usd residencia      remoto empresa tamanho_empresa residencia_iso3
# 0  214000         US      Remoto      US           Médio             USA
# 1  136000         US      Remoto      US           Médio             USA
# 2  158800         AU  Presencial      AU           Médio             AUS
# 3  139200         AU  Presencial      AU           Médio             AUS
# 4   90000         US  Presencial      US           Médio             USA

# %%
df_limpo.to_csv('dados-imersao-final.csv', index=False)

# %% [markdown]
# Aula 4 - Construindo um Dashboard com Streamlit
# Aprender a usar a biblioteca Streamlit para a criação de um dashboard interativo simples, que permite visualizar dados filtrados e gerar gráficos de forma prática.

# %%
import streamlit as st
import pandas as pd
import plotly.express as px
# Configuração da página do Streamlit
# Define o título, ícone e layout da página do Streamlit.
# O layout é definido como "wide" para ocupar toda a largura da tela.

st.set_page_config(page_title="Dashboard de Salários na Àrea de Dados", page_icon="📊", layout="wide",)

df = pd.read_csv("https://raw.githubusercontent.com/vqrca/dashboard_salarios_dados/refs/heads/main/dados-imersao-final.csv")

# --- Barra Lateral (Filtros) ---
st.sidebar.header("🔍 Filtros")

# Filtro de Ano
anos_disponiveis = sorted(df['ano'].unique())
anos_selecionados = st.sidebar.multiselect("Ano", anos_disponiveis, default=anos_disponiveis)

# Filtro de Senioridade
senioridades_disponiveis = sorted(df['senioridade'].unique())
senioridades_selecionadas = st.sidebar.multiselect("Senioridade", senioridades_disponiveis, default=senioridades_disponiveis)

# Filtro por Tipo de Contrato
contratos_disponiveis = sorted(df['contrato'].unique())
contratos_selecionados = st.sidebar.multiselect("Tipo de Contrato", contratos_disponiveis, default=contratos_disponiveis)

# Filtro por Tamanho da Empresa
tamanhos_disponiveis = sorted(df['tamanho_empresa'].unique())
tamanhos_selecionados = st.sidebar.multiselect("Tamanho da Empresa", tamanhos_disponiveis, default=tamanhos_disponiveis)

# --- Filtragem do DataFrame ---
# O dataframe principal é filtrado com base nas seleções feitas na barra lateral.
df_filtrado = df[
    (df['ano'].isin(anos_selecionados)) &
    (df['senioridade'].isin(senioridades_selecionadas)) &
    (df['contrato'].isin(contratos_selecionados)) &
    (df['tamanho_empresa'].isin(tamanhos_selecionados))
]

# --- Conteúdo Principal ---
st.title("🎲 Dashboard de Análise de Salários na Área de Dados")
st.markdown("Explore os dados salariais na área de dados nos últimos anos. Utilize os filtros à esquerda para refinar sua análise.")

# --- Métricas Principais (KPIs) ---
st.subheader("Métricas gerais (Salário anual em USD)")

if not df_filtrado.empty:
    salario_medio = df_filtrado['usd'].mean()
    salario_maximo = df_filtrado['usd'].max()
    total_registros = df_filtrado.shape[0]
    cargo_mais_frequente = df_filtrado["cargo"].mode()[0]
else:
    salario_medio, salario_mediano, salario_maximo, total_registros, cargo_mais_comum = 0, 0, 0, ""

col1, col2, col3, col4 = st.columns(4)
col1.metric("Salário médio", f"${salario_medio:,.0f}")
col2.metric("Salário máximo", f"${salario_maximo:,.0f}")
col3.metric("Total de registros", f"{total_registros:,}")
col4.metric("Cargo mais frequente", cargo_mais_frequente)

st.markdown("---")

# --- Análises Visuais com Plotly ---
st.subheader("Gráficos")

col_graf1, col_graf2 = st.columns(2)

with col_graf1:
    if not df_filtrado.empty:
        top_cargos = df_filtrado.groupby('cargo')['usd'].mean().nlargest(10).sort_values(ascending=True).reset_index()
        grafico_cargos = px.bar(
            top_cargos,
            x='usd',
            y='cargo',
            orientation='h',
            title="Top 10 cargos por salário médio",
            labels={'usd': 'Média salarial anual (USD)', 'cargo': ''}
        )
        grafico_cargos.update_layout(title_x=0.1, yaxis={'categoryorder':'total ascending'})
        st.plotly_chart(grafico_cargos, use_container_width=True)
    else:
        st.warning("Nenhum dado para exibir no gráfico de cargos.")

with col_graf2:
    if not df_filtrado.empty:
        grafico_hist = px.histogram(
            df_filtrado,
            x='usd',
            nbins=30,
            title="Distribuição de salários anuais",
            labels={'usd': 'Faixa salarial (USD)', 'count': ''}
        )
        grafico_hist.update_layout(title_x=0.1)
        st.plotly_chart(grafico_hist, use_container_width=True)
    else:
        st.warning("Nenhum dado para exibir no gráfico de distribuição.")

col_graf3, col_graf4 = st.columns(2)

with col_graf3:
    if not df_filtrado.empty:
        remoto_contagem = df_filtrado['remoto'].value_counts().reset_index()
        remoto_contagem.columns = ['tipo_trabalho', 'quantidade']
        grafico_remoto = px.pie(
            remoto_contagem,
            names='tipo_trabalho',
            values='quantidade',
            title='Proporção dos tipos de trabalho',
            hole=0.5
        )
        grafico_remoto.update_traces(textinfo='percent+label')
        grafico_remoto.update_layout(title_x=0.1)
        st.plotly_chart(grafico_remoto, use_container_width=True)
    else:
        st.warning("Nenhum dado para exibir no gráfico dos tipos de trabalho.")

with col_graf4:
    if not df_filtrado.empty:
        df_ds = df_filtrado[df_filtrado['cargo'] == 'Data Scientist']
        media_ds_pais = df_ds.groupby('residencia_iso3')['usd'].mean().reset_index()
        grafico_paises = px.choropleth(media_ds_pais,
            locations='residencia_iso3',
            color='usd',
            color_continuous_scale='rdylgn',
            title='Salário médio de Cientista de Dados por país',
            labels={'usd': 'Salário médio (USD)', 'residencia_iso3': 'País'})
        grafico_paises.update_layout(title_x=0.1)
        st.plotly_chart(grafico_paises, use_container_width=True)
    else:
        st.warning("Nenhum dado para exibir no gráfico de países.")

# --- Tabela de Dados Detalhados ---
st.subheader("Dados Detalhados")
st.dataframe(df_filtrado)

# %% [markdown]
# streamlit run app.py
